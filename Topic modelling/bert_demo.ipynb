# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0   Public calendar for SmartThings developer events
# 1           1  SmartThings use in a restaurant / business - R...
# 2           2  Shutting something off after power usage excee...
# 3           3                [BETA] Community SmartApp Installer
# 4           4  'Fibaro Z-Wave FGK-101 Temperature & Door/Wind...
#
#                               tag         subtag  \
# 0                 Groups & Events            NaN
# 1              Projects & Stories            NaN
# 2         SmartApps & Automations            NaN
# 3     Community Created SmartApps  smartapp_misc
# 4  Community Created Device Types         fibaro
#
#                                                  url  \
# 0  https://community.smartthings.com/t/public-cal...
# 1  https://community.smartthings.com/t/smartthing...
# 2  https://community.smartthings.com/t/shutting-s...
# 3  https://community.smartthings.com/t/beta-commu...
# ...

# %%
subdata = data[["tag","starter_content"]]
subdata.head()
# Out:
#                               tag  \
# 0                 Groups & Events
# 1              Projects & Stories
# 2         SmartApps & Automations
# 3     Community Created SmartApps
# 4  Community Created Device Types
#
#                                      starter_content
# 0  dear community in 2015 we are going to do a be...
# 1  this post is partially out of boredom looking ...
# 2  hi i have a coffee grinder that my employees a...
# 3  ok i’m ready to finally share this with the co...
# 4  the fibaro fgk101 temperature doorwindow senso...

# %%
# !pip install transformers

# %%
import numpy as np
import pandas as pd
import torch
import transformers as ppb
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.BertModel, ppb.BertTokenizer, 'bert-base-uncased')

# %%
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

# %%
tokenized = subdata['starter_content'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (575 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (627 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (6955 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (984 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2699 > 512). Running this sequence through the model will result in indexing errors
# ...

# %%
tokenized
# Out:
# 0       [101, 6203, 2451, 1999, 2325, 2057, 2024, 2183...
# 1       [101, 2023, 2695, 2003, 6822, 2041, 1997, 2955...
# 2       [101, 7632, 1045, 2031, 1037, 4157, 23088, 212...
# 3       [101, 7929, 1045, 1521, 1049, 3201, 2000, 2633...
# 4       [101, 1996, 13651, 3217, 1042, 2290, 2243, 107...
#                               ...
# 2995    [101, 10449, 23964, 10200, 2006, 5227, 2013, 5...
# 2996    [101, 1045, 1521, 2310, 2018, 1037, 2358, 6462...
# 2997    [101, 3087, 2113, 1997, 1037, 6819, 2094, 1999...
# 2998    [101, 7632, 2045, 10047, 6603, 2065, 2045, 200...
# 2999    [101, 2197, 2733, 3143, 2041, 4270, 23579, 193...
# Name: starter_content, Length: 3000, dtype: object

# %%
len(tokenized[1])
# Out:
# 512

# %%
maxlength = 512

# %%
padded= tokenized.copy()
for i in range(len(padded)):
    padded[i] +=[0] * (maxlength - len(padded[i]))
    padded[i] =  padded[i][:maxlength] #cut
    padded[i] = np.array(padded[i],dtype = int).astype(int)
padded = np.array(padded)

# %%
padded_array = []
for i in range(len(padded)):
    padded_array+=[padded[i]]
#converting to

# %%
input_ids = torch.tensor(padded_array[:11]) #First 10 posts with 512 words

# %%
input_ids
# Out:
# tensor([[ 101, 6203, 2451,  ...,    0,    0,    0],
#         [ 101, 2023, 2695,  ...,    0,    0,    0],
#         [ 101, 7632, 1045,  ..., 4311, 1996, 2373],
#         ...,
#         [ 101, 1048, 2290,  ...,    0,    0,    0],
#         [ 101, 2074, 3641,  ...,    0,    0,    0],
#         [ 101, 1039, 2581,  ...,    0,    0,    0]])

# %%
with torch.no_grad():
    last_hidden_states = model(input_ids)

# %%
last_hidden_states
# Out:
# (tensor([[[-0.3857,  0.4848, -0.4195,  ..., -0.5974,  0.5283, -0.5646],
#           [ 0.2969,  0.4912,  1.8841,  ..., -0.7132,  0.1056, -0.5728],
#           [ 0.4561,  0.1590,  0.4130,  ..., -0.6608,  0.7095, -0.5545],
#           ...,
#           [ 0.3842,  0.2431,  0.2822,  ..., -0.5593, -0.2813, -1.1975],
#           [ 0.4625,  0.1130,  0.3306,  ..., -0.5721, -0.2449, -1.2194],
#           [ 0.1475,  0.3604,  0.3457,  ..., -0.8699, -0.1485, -1.4391]],
#
#          [[-0.2015,  0.5497,  0.0413,  ..., -0.3196,  0.6730, -0.0865],
#           [-0.7250,  0.3403,  0.0824,  ..., -0.6253,  1.1320,  0.3600],
#           [ 0.4290,  0.1555,  0.3337,  ...,  0.1953,  0.2552,  1.0583],
#           ...,
#           [ 0.0200,  0.3830,  0.3698,  ..., -0.5113,  0.0835, -1.4787],
#           [ 0.1858,  0.3151,  0.3600,  ..., -0.6436,  0.2177, -1.4903],
#           [ 0.1172,  0.4073,  0.2702,  ..., -0.6609,  0.3157, -1.4912]],
#
# ...

# %%
features = last_hidden_states[0][:,0,:].numpy()

# %%
features
# Out:
# array([[-0.38565946,  0.48476657, -0.41951433, ..., -0.5973534 ,
#          0.52827424, -0.5646404 ],
#        [-0.2014719 ,  0.5496753 ,  0.04134096, ..., -0.3195762 ,
#          0.67300785, -0.08645611],
#        [ 0.35334244, -0.04135975,  0.23433143, ..., -0.17416245,
#         -0.05767354,  0.26405624],
#        ...,
#        [-0.39257872,  0.61365384,  0.14244711, ..., -0.64162195,
#          0.65161026, -0.53432536],
#        [-0.47292608,  0.50554323, -0.30911985, ..., -0.56305444,
#          0.8321308 , -0.41225857],
#        [-0.32878745,  0.5975668 ,  0.0507755 , ..., -0.5329023 ,
#          0.5965111 , -0.6757047 ]], dtype=float32)

# %%
len(features[0])
# Out:
# 768

# %%
data['tag'][0]
# Out:
# 'Groups & Events'
