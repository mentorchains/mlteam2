# %%
import requests
import pandas
from bs4 import BeautifulSoup
from collections import defaultdict

topics = []
tags = []
href = []
authors = []
content = []

base = "https://community.smartthings.com"

page = "/latest?no_definitions=true&page="

#Go through two scrolls
for num in range(2):
    response = requests.get(base + page + str(num))

    soup = BeautifulSoup(response.content, 'html.parser')

    #print(soup)

    #Find all the tags starting with 'a'

    #For all the topic headings
    for link in soup.find_all('meta', {'itemprop': 'name'}):
        #Add the topic to the list
        topics.append(link['content'])

    #For all the categories that appear under the topics
    for link in soup.find_all('span', {'class': 'category-name'}):
        #Add the category to the list
        tags.append(link.text)

    #For all the URLs that each topic leads to
    for link in soup.find_all('meta', {'itemprop': 'url'}):
        #Add the URL to the list
        url = link['content'].split("/")
        #Single out the extension (for practice)
        href.append("/" + url[3] + "/" + url[4] + "/" + url[5])

    ### OLD CODE ###
    #lambda makes a mini function. In this case the mini function is
        # sort by index=1, aka the number of times the tag appears.
    #reverse=True sorts it into descending order.
        
    #for k, v in sorted(tags.items(), key = lambda item: item[1], reverse=True):
    #for index in range(len(topics)):
    #   print("TOPIC: " + topics[index])
    #   print("CATEGORY: " + tags[index] + "\n")

#response = requests.get(base + href[0])
#print(BeautifulSoup(response.content, 'html.parser'))
#print("\n\n\n")

#Go to each topic page
for extension in href:
    response = requests.get(base + extension)
    soup = BeautifulSoup(response.content, 'html.parser')

    #print(soup)

    #Find the place where the username is located
    link1 = soup.find('span', {'itemprop': 'author'})

    #Go into the <a> tag inside the <span> tag
    link2 = link1.find('a')
    #Get the author from the text in the tag
    authors.append(link2.text)

    #Find the article body
    body = soup.find('div', {'itemprop': 'articleBody'})
    text = ""
    #Concatenate all the paragraphs that make up the article content
    for message in body.find_all('p'):
        text += message.text + " "

    #Add the content to the list
    content.append(text)
    #print(text)
    #print("\n")

#Create a table (Pandas Data Frame)
table = pandas.DataFrame()
table["Topic"] = topics
table["Category"] = tags
table["Author"] = authors
table["Text"] = content 

print(table)
# Out:
#                                                 Topic  \
# 0    Public calendar for SmartThings developer events
# 1   2018 - Current: Custom Graber Virtual Cord Z-w...
# 2                       Get ready to make the switch!
# 3   [RELEASE] My Next ManagerV2 for your Nest® pro...
# 4              Disarm button disappeared from app ADT
# 5                               MyQ Garage app alerts
# 6           No Hub In Your Current Location (New App)
# 7      [RELEASE] Fully Kiosk Browser Controller (DTH)
# 8   [RELEASE] Virtual Garage Door Opener/Controlle...
# 9   Sonos Voice Notification Issues (Sound doesn't...
# 10  [RELEASE] Neato (Connect) V1.2.6c (Botvac Conn...
# 11                [BETA] Community SmartApp Installer
# 12  'Fibaro Z-Wave FGK-101 Temperature & Door/Wind...
# 13  Some Time-Based Restrictions Suddenly Being Ig...
# 14           Globe Suite and ST Integration is Broken
# 15  Integrating window shades with SmartThings (Ax...
# 16             Withings Scales integration (May 2020)
# 17  [Released] ADT Tools 2 for Smartthings ADT ala...
# 18         Device Handler for Aqara Wired Wall Switch
# 19                     Water sensor - shutoff valves?
# 20                                Pentair ScreenLogic
# 21      [RELEASE] ST_Anything - Arduino/ESP8266/ESP32
# 22                                   Vid enhancement?
# 23                    Notifications on Samsung Q70 TV
# 24  Connecting 3rd party Smart sockets to the Smar...
# 25  SmartThings motion sensor automation notificat...
# 26  [BETA] Wink Relay - Custom SmartThings Integra...
# 27            Zooz 4-in-1 Sensor - can't turn LED off
# 28  Integrating WiFi Switches/Plugs that use the T...
# 29  How much does my ST home system need a broadba...
# 30                      [RELEASE] Simple Event Logger
# 31  [RELEASE] Tesla Powerwall Manager Smart App an...
# 32                                      Rule problems
# 33     Ideas on making push button light switch smart
# 34          XML or JSON data as a Temperature sensor?
# 35  [BETA] AirScape Whole House Fan (Gen 2.0) Devi...
# 36            Color Indicator split into 255 segments
# 37           Status of Dashboard Tile: iOS vs Android
# 38                  Dropbox Motion Sensor (Swann DVR)
# 39  Ecolink door sensor 4655BC0-R, has anybody use...
# 40                          Z-Wave Boiler Programmer?
# 41            Simple SmartApp Tutorial (SmartApp SDK)
# 42                                 Garden Lights (UK)
# 43               [RELEASE] Lock User Management (LUM)
# 44          Samsung Multiroom + Spotify + Amazon Echo
# 45                         Samsung TV - Can't Turn On
# 46  Is there a working example of a button subscri...
# 47  [RELEASE] Orbit Bhyve Controller - Hose Faucet...
# 48                   Ikea button (dimmer) not working
# 49    Xiaomi Mi Smart Plug (New Model) Device Handler
# 50       Enbrighten new Zigbee 3.0 devices (May 2020)
# 51  4-Pack Sylvania 65W Equivalent Smart+ ZigBee C...
# 52  [RELEASE] Nuki Manager for Nuki Smart Lock(App...
# 53  Integration of MiLight, LimitlessLED, Easybulb...
# 54                 Device handlers for Fibaro fgk101?
# 55                Request Help - LAN JSON get request
# 56  Getting volvo on call integrated to smartthing...
# 57                    Can't automate a lighting group
# 58         Any Concord 4 alarm panel users out there?
# 59                            Power outage and lights
#
#                           Category             Author  \
# 0                  Groups & Events              mager
# 1           Devices & Integrations        ZebraBlinds
# 2                    Announcements        SmartThings
# 3   Community Created Device Types         yvesracine
# 4           Devices & Integrations        Davidgostbo
# 5           Devices & Integrations          Mkstretch
# 6                   Apps & Clients     philly33flyers
# 7      Community Created SmartApps               arnb
# 8   Community Created Device Types               RBoy
# 9           Devices & Integrations           Wolfpack
# 10     Community Created SmartApps            Alyc100
# 11     Community Created SmartApps           tonesto7
# 12  Community Created Device Types              geeji
# 13              General Discussion        sgnihttrams
# 14          Devices & Integrations           Flakie99
# 15          Devices & Integrations          Team_AXIS
# 16          Devices & Integrations                jkp
# 17     Community Created SmartApps         Mavrrick58
# 18                Connected Things              simic
# 19         SmartApps & Automations            tjodork
# 20                Connected Things            BBoy486
# 21              Projects & Stories            ogiewon
# 22            Writing Device Types             rym002
# 23          Devices & Integrations         radiocolin
# 24          Devices & Integrations     King_of_Sicily
# 25         SmartApps & Automations     King_of_Sicily
# 26              Projects & Stories        joshua_lyon
# 27          Devices & Integrations            cstolze
# 28                             FAQ          JDRoberts
# 29                Connected Things           wtsang01
# 30     Community Created SmartApps      krlaframboise
# 31  Community Created Device Types             Darwin
# 32              General Discussion              Joerg
# 33              Projects & Stories       DOWNSOUTH407
# 34          Devices & Integrations           Jirka_CL
# 35  Community Created Device Types          tgsoverly
# 36            Writing Device Types        rcarmichael
# 37   SmartThings (Samsung Connect)         stillerson
# 38         SmartApps & Automations         lmullineux
# 39          Devices & Integrations  Jesus_Jose_Mendez
# 40              General Discussion              ghesp
# 41               Writing SmartApps     jody.albritton
# 42                    Device Ideas              vikas
# 43     Community Created SmartApps               RBoy
# 44          Devices & Integrations        matthewg156
# 45              General Discussion               face
# 46               Writing SmartApps           wtsang01
# 47     Community Created SmartApps        kurtsanders
# 48                Connected Things              Spaka
# 49          Devices & Integrations          robertash
# 50          Devices & Integrations                jkp
# 51                           Deals                jkp
# 52  Community Created Device Types               RBoy
# 53              Projects & Stories        brianfreund
# 54              General Discussion          Jjimbardo
# 55            Writing Device Types          yandreev3
# 56          Devices & Integrations              chali
# 57             Features & Feedback             Diggie
# 58                Connected Things         sgonsalves
# 59                Automation Ideas             Dan999
#
#                                                  Text
# 0   Dear community, In 2015, we’re going to do a b...
# 1   Full Disclaimer: We are dealers of Graber prod...
# 2   Hi Everyone, Many of the features from SmartTh...
# 3   _ If you have lost your auth tokens from Nest ...
# 4   Hi guys, have y’all noticed that adt Samsung a...
# 5   Ok so I setup 1 Alert and clicked opened stopp...
# 6   I’m trying to add a new S2 switch with QR code...
# 7   Gavin Campbell developed this driver for Hubit...
# 8   On overwhelming requests from users: This solu...
# 9   I just purchased a Sonos Playbar and love that...
# 10  Announcing the new Neato (Connect) SmartApp an...
# 11  I want to start off by saying thanks to @corey...
# 12  The Fibaro FGK-101 Temperature & Door/Window s...
# 13  [NOTE: I posted about this over on the webCoRE...
# 14  Had some issues with lights being offline and ...
# 15  Hey everyone, We’re launching a device that ta...
# 16  This thread is where you can post questions or...
# 17  ADT Tools has had turned into a very useful to...
# 18  ** This DTH is no longer supported ** Pls refe...
# 19  I initially intended to copy FloodStop devices...
# 20  Has anyone gotten their IntelliQuick Screen Lo...
# 21  ST_Anything allows you to integrate a custom A...
# 22  Is there any process file bug reports on exist...
# 23  My Ring doorbell is able to put up a toast on ...
# 24  So I came to SmartThings via LightwaveRF produ...
# 25  Hi. Just bought the V3 SmartThings Hub and IM6...
# 26  I’ve developed a custom integration for connec...
# 27  I just purchased 2 Zooz 4-in-1 sensors, and I ...
# 28  It looks like there is the Mojocraft Wireless ...
# 29  What still works if I lose broadband? (Or, if ...
# 30  Simple Event Logger is a fully customizable Sm...
# 31  This is a beta release smart app and device ha...
# 32  hello everyone,\ni have a problem with rules. ...
# 33  I am trying to make a 1920’s push button type ...
# 34  Hi guys, any idea how to connect data from xml...
# 35  I have a device handler that allows for the au...
# 36  Hello,\nI am trying to make a DTH for a “Mi Li...
# 37  I use the “new” Connect app, last update 1.7.4...
# 38  Hi I’m brand new to smartthings, so please bar...
# 39  I wanna buy these door sensors, but I can’t fi...
# 40  I’ve already got a Nest 2nd Gen thermostat, an...
# 41  This SDK builds on the CoreSDK and provides ki...
# 42  Hi All, I am planning to setup a bespoke daisy...
# 43  It works with the standard Z-Wave Lock/ZigBee ...
# 44  I have a Samsung Multiroom speaker setup, and ...
# 45  Samsung Hub and Alexa Added Samsung TV to Hub,...
# 46  I’ve tried to set up a handler to be called wh...
# 47  Today, I am pleased to provide the ST Communit...
# 48  Hello, I have recently bought Ikea button(dimm...
# 49  Hi everyone! Does anyone know if there is a de...
# 50  https://byjasco.com/enbrighten-zigbee-in-wall-...
# 51  3rd party seller (  88% positive in the last 1...
# 52  This Nuki Manager was created in conjunction w...
# 53  Hopefully this helps other users avoid the hea...
# 54  It’s like I can’t execute a device handler. Pu...
# 55  I have spent all day reading the forum and tes...
# 56  Hi is it anyone that have integrated volvo on ...
# 57  It is nice that the ST app lets you add lights...
# 58  Just ordered the GE Superbus 2000 automation m...
# 59  We had our first power outage since I installe...
