# %%
import urllib
link = "https://forum.schizophrenia.com/"
file= urllib.request.urlopen(link)
data = file.read()
print(data)
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n  <head>\n    <meta charset="utf-8">\n    <title>Schizophrenia.com - Schizophrenia Discussion Community for People Diagnosed</title>\n    <meta name="description" content="Schizophrenia Discussion Community for People Diagnosed, or who think they may have Psychosis.">\n    <meta name="generator" content="Discourse 2.5.0.beta5 - https://github.com/discourse/discourse version c8370b9c78df1161aa3db2699bbd53c3e04b9925">\n<link rel="icon" type="image/png" href="https://aws1.discourse-cdn.com/schizophrenia/uploads/default/optimized/3X/0/6/061bf9f198a2b7788e513378513ad6875b248769_2_32x32.png">\n<link rel="apple-touch-icon" type="image/png" href="https://aws1.discourse-cdn.com/schizophrenia/uploads/default/optimized/3X/0/6/061bf9f198a2b7788e513378513ad6875b248769_2_180x180.png">\n<meta name="theme-color" content="#f7f7f7">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=yes, viewport-fit=cover">\n
# ...

# %%
import re

# %%
# !pip install selenium

# %% [raw]
# Download chrome driver from https://sites.google.com/a/chromium.org/chromedriver/downloads
# which mataches your Chrome verision
# (If you don't know your Chrome version, open Chrome and click the three dots icon on the top right. click help-About Google Chrome to get your version)
# put the driver in the same directory as this notebook

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pickle

# %%
#url = "https://forums.fractalfuture.net"
url = "https://forum.schizophrenia.com/"
options = webdriver.ChromeOptions()
#options.add_argument('--incognito')
#options.add_argument('--headless')
#options.add_argument('--no-sandbox')
driver = webdriver.Chrome(executable_path = './chromedriver', options = options)
driver.get(url)
page = driver.execute_script('return document.body.innerHTML')
soup = BeautifulSoup(''.join(page),'html.parser')

# %%
print(soup.text)
# Out:
#
# HomeAboutContact usFAQ
#
#
#
# Schizophrenia.com
# Sign UpLog In
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       all categories
#
#
#
#
#
#
#
#
#
#
#
#
#   Latest
#
#
#
#   Top
#
#
#
#   Categories
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ADVERTISEMENT
#
#
#
#
#
#
#
#
#
#
#
# Topic
#
# Replies
# Views
# Activity
#
#
#
#
#
#
#
#
# L-theanine is Effective in Lessening Positive Symptoms, and improving Sleep Quality in patients with schizophrenia
#
#
# News
#
#
#     CONCLUSIONS:
#
# Our results suggest that l-theanine is effective in ameliorating positive symptoms and sleep quality in schizophrenia
#
# Dose:   l-Theanine (250 mg/day)
#
#
#
#
# more information on L-Theanine
#
#
#
#
# WHERE TO BUY…
#       read more
#
#
#
#
#
#
#
#
#
#
#
# 337
#
#
# 57.8k
#
# 9h
#
#
#
#
#
#
#
# Sarcosine Reduces Symptoms in Schizophrenia
#
#
# DX'd - Other
#
#
# ...

# %%
type(soup.text)
# Out:
# str

# %%
soup.text
# Out:
# "\n\n\n \nHomeAboutContact usFAQ\n\n\n\nSchizophrenia.com\nSign UpLog In\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \n\n\n      all categories\n    \n \n\n\n\n\n\n\n\n\n\n \n  Latest\n\n\n\n  Top\n\n\n\n  Categories\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n   ADVERTISEMENT\n\n\n\n\n\n\n\n\n\n\n \nTopic\n\nReplies\nViews\nActivity\n\n\n\n\n\n\n\n\nL-theanine is Effective in Lessening Positive Symptoms, and improving Sleep Quality in patients with schizophrenia\n\n\nNews\n\n\n    CONCLUSIONS: \n\nOur results suggest that l-theanine is effective in ameliorating positive symptoms and sleep quality in schizophrenia \n\nDose:   l-Theanine (250 mg/day) \n\n\n\n\nmore information on L-Theanine \n\n\n\n\nWHERE TO BUY…\n      read more\n\n\n\n\n\n\n\n\n\n\n\n337\n\n\n57.8k\n\n9h\n\n\n\n\n\n\n\nSarcosine Reduces Symptoms in Schizophrenia\n\n\nDX'd - Other\n\n\n    There has been quite a bit of good research over the past 8 years on a dietary supplement called Sarcosine (or N-methyl Glycin
# ...

# %%
re.search('guitar',soup.text)

# %%
re.findall(r"\w+ly", soup.text)
# Out:
# ['Gly', 'family', 'family']
